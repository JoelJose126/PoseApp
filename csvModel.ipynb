# %%
import csv
import cv2
import mediapipe as mp

mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
cap=cv2.VideoCapture(0)
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        # Read a frame from the video capture
        success, image = cap.read()
        if not success:
            break
        
        # Convert the image to grayscale and run the Mediapipe Pose model
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image.flags.writeable=False
        results = pose.process(image)
        
        image.flags.writeable=True
        
        red=(255,0,0)
        green=(0,255,0)
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=red, thickness=2, circle_radius=2),
                                 mp_drawing.DrawingSpec(color=green,thickness=1, circle_radius=2)
                                  )
        cv2.imshow("Raw Webcam Feed",image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
                break
                
                
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
width=cap.get(cv2.CAP_PROP_FRAME_WIDTH)
fps=cap.get(cv2.CAP_PROP_FPS)
videoWriter = cv2.VideoWriter(r"G:\Project\Self video Samples\Bicep curl\bpress.avi", cv2.VideoWriter_fourcc('P', 'I', 'M', '1'), fps, (int(width), int(height)))


while cap.isOpened():
    ret, frame = cap.read()
    try:
        cv2.imshow("Press", frame)
        videoWriter.write(frame)
    except Exception as e:
        break
        
    if cv2.waitKey(10) & 0xFF ==ord('q'):
        break 
cap.release()
videoWriter.release()
cv2.destroyAllWindows()

# %%
import csv
import os
import numpy as np
from matplotlib import pyplot

# %%
landmarks=['class']
for val in range(1,33+1):
    landmarks+=['x{}'.format(val),'y{}'.format(val),'z{}'.format(val),'v{}'.format(val)]
landmarks[1:]
# Out:
# ['x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
# ...

# %%
with open(r"G:\Project\Self video Samples\Bicep curl\coords1.csv", mode='w', newline='') as f:
    csv_writer = csv.writer (f, delimiter=',', quotechar='"',quoting=csv.QUOTE_MINIMAL) 
    csv_writer.writerow(landmarks)

# %%
def export_landmark (results, action):
    try:
        keypoints = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() 
        row = np.insert(keypoints,0, action)
        with open("G:\Project\Self video Samples\Bicep curl\coords1.csv", mode='a', newline='') as f:
            csv_writer = csv.writer (f, delimiter=',', quotechar='"',quoting=csv.QUOTE_MINIMAL) 
            
            csv_writer.writerow(row)
    except Exception as e:
        print(e)

# %%
export_landmark(results,1)
results.pose_landmarks
# Out:
# landmark {
#   x: 0.42592114210128784
#   y: 0.4679785370826721
#   z: -0.9942814111709595
#   visibility: 0.9998552799224854
# }
# landmark {
#   x: 0.4476417005062103
#   y: 0.40411800146102905
#   z: -0.9746241569519043
#   visibility: 0.9997940063476562
# }
# landmark {
#   x: 0.46197834610939026
#   y: 0.4016661047935486
#   z: -0.9742680788040161
#   visibility: 0.999772310256958
# }
# landmark {
#   x: 0.47495388984680176
#   y: 0.3994966447353363
#   z: -0.974270224571228
#   visibility: 0.9997419714927673
# }
# landmark {
#   x: 0.3976215720176697
#   y: 0.40834397077560425
#   z: -0.9740033149719238
#   visibility: 0.9998258948326111
# }
# landmark {
#   x: 0.379149466753006
#   y: 0.40874865651130676
#   z: -0.9735170602798462
#   visibility: 0.9998030662536621
# }
# landmark {
#   x: 0.3636925220489502
#   y: 0.4089719355106354
#   z: -0.9736075401306152
#   visibility: 0.999805212020874
# }
# landmark {
#   x: 0.4897972047328949
#   y: 0.40430527925491333
# ...

# %%
cap=cv2.VideoCapture(r"G:\Project\Self video Samples\Bicep curl\20230601_095624.mp4")
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        # Read a frame from the video capture
        success, image = cap.read()
        if not success:
            break
        
        # Convert the image to grayscale and run the Mediapipe Pose model
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image=cv2.resize(image,(640,480))
        image.flags.writeable=False
        results = pose.process(image)
        
        image.flags.writeable=True
        
        red=(255,0,0)
        green=(0,255,0)
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=red, thickness=2, circle_radius=2),
                                 mp_drawing.DrawingSpec(color=green,thickness=1, circle_radius=2)
                                  )
       
        k=cv2.waitKey(1)
        if (k== 119):
            export_landmark(results,2)
        
        if (k== 115):
            export_landmark(results,1)
            
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        cv2.imshow("Video Feed",image)
        
        if cv2.waitKey(10) & 0xFF ==ord('q'):
            break        
                
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
#       3     while cap.isOpened():
#       4         # Read a frame from the video capture
# ----> 5         success, image = cap.read()
#       6         if not success:
#       7             break
#
# KeyboardInterrupt:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import pickle 
df=pd.read_csv(r"G:\Project\Self video Samples\Bicep curl\coords1.csv")
df.head()
# Out:
#    class        x1        y1        z1        v1        x2        y2  \
# 0    1.0  0.465821  0.196120 -0.374095  0.999308  0.476192  0.185936
# 1    1.0  0.465642  0.195084 -0.318733  0.999364  0.476653  0.185208
# 2    1.0  0.464476  0.194031 -0.363642  0.999370  0.476892  0.184479
# 3    1.0  0.463909  0.192016 -0.361543  0.999372  0.476237  0.183135
# 4    1.0  0.463902  0.192596 -0.416994  0.999250  0.476752  0.183105
#
#          z2        v2        x3  ...       z31       v31       x32       y32  \
# 0 -0.340541  0.998286  0.485372  ... -0.248263  0.914288  0.644627  0.958991
# 1 -0.283794  0.998433  0.486264  ... -0.241636  0.915630  0.644572  0.958892
# 2 -0.330548  0.998479  0.486562  ... -0.211582  0.917291  0.644356  0.958878
# 3 -0.329577  0.998527  0.486314  ... -0.213530  0.916129  0.644408  0.958786
# 4 -0.389895  0.998166  0.486827  ... -0.153042  0.914041  0.643339  0.958932
#
#         z32       v32       x33       y33       z33       v33
# ...

# %%
df.shape
# Out:
# (327, 133)

# %%
X=df.drop('class',axis=1)
y=df['class']

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.3,random_state=43)
# Out:
# 2      1.0
# 312    2.0
# 210    2.0
# 165    1.0
# 62     2.0
#       ...
# 277    1.0
# 305    2.0
# 255    1.0
# 320    1.0
# 324    1.0
# Name: class, Length: 228, dtype: float64

# %%
from sklearn.pipeline import make_pipeline
from sklearn. preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression 
from sklearn.linear_model import RidgeClassifier
from sklearn. ensemble import RandomForestClassifier
from sklearn. ensemble import GradientBoostingClassifier
pipelines = {
'lr':make_pipeline (StandardScaler(), LogisticRegression()),
'rc':make_pipeline (StandardScaler (), RidgeClassifier()),
'rf':make_pipeline (StandardScaler(), RandomForestClassifier()),
'gb':make_pipeline (StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model=pipeline.fit(X_train, y_train)
    fit_models [algo] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array([2., 2., 2., 1., 2., 2., 1., 1., 2., 2., 2., 2., 1., 1., 1., 1., 2.,
#        1., 2., 2., 2., 2., 1., 1., 2., 2., 2., 1., 1., 2., 1., 2., 1., 1.,
#        2., 1., 2., 1., 1., 1., 1., 1., 1., 2., 1., 2., 1., 1., 1., 2., 2.,
#        1., 2., 1., 2., 1., 1., 1., 1., 2., 2., 2., 2., 2., 1., 1., 2., 1.,
#        1., 2., 2., 2., 2., 2., 1., 2., 2., 2., 2., 1., 1., 2., 2., 2., 1.,
#        2., 2., 2., 2., 2., 2., 2., 1., 1., 1., 2., 1., 2., 1.])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score # Accuracy metrics import pickle
yhat = model.predict(X_test)
for algo, model in fit_models.items(): 
    print(algo, accuracy_score (y_test.values, yhat), precision_score (y_test.values, yhat, average="binary"),
          recall_score (y_test.values, yhat, average="binary"))
# Out:
# lr 1.0 1.0 1.0
# rc 1.0 1.0 1.0
# rf 1.0 1.0 1.0
# gb 1.0 1.0 1.0

# %%
yhat =fit_models['lr'].predict(X_test)

# %%
yhat[:10]
# Out:
# array([2., 2., 2., 1., 2., 2., 1., 1., 2., 2.])

# %%
with open(r"G:\Project\Self video Samples\Bicep curl\/Bcurl_cvs_Logr.pkl", 'wb') as f: 
    pickle.dump(fit_models['rf'], f)

# %%
with open(r"G:\Project\Self video Samples\Bicep curl\/Bcurl_cvs_Logr.pkl", 'rb') as f:
    model=pickle.load(f)

# %%
cap = cv2.VideoCapture(3) with mp_pose.Pose (min_detection_confidence 0.5, min_tracking_confidence 0.5) as pose:
#Initiate holistic model
while cap.isOpened():
    ret, frame = cap.read()
# Recolor Feed
    image cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
# Make Detections
    results = pose.process(image)
# Recolor image back to BGR for rendering
    image.flags.writeable = True image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=red, thickness=2, circle_radius=2),
                                 mp_drawing.DrawingSpec(color=yellow, thickness=1, circle_radius=2)
                                 )

# %%
import cv2
import mediapipe as mp
import pickle

# Load the trained pickle model
with open(r"G:\Project\Self video Samples\Bicep curl\/Bcurl_cvs_Logr.pkl", 'rb') as f:
    model = pickle.load(f)

# Define the classes for pose classification
pose_classes = {1:'Down', 2:'UP',}

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5, min_tracking_confidence=0.5,smooth_landmarks=True)

# OpenCV setup for video capture
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise Exception("Failed to open the camera.")

while True:
    # Read frame from camera
    ret, frame = cap.read()
    if not ret:
        break
    
    # Convert BGR image to RGB
    frame=cv2.flip(frame,1)
    image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame with MediaPipe Pose
    results = pose.process(image_rgb)

    # Check if landmarks are detected
    if results.pose_landmarks:
        # Extract landmarks
        landmarks = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()
        
        # Perform pose classification using the pickle model
        predicted_class = model.predict([landmarks])[0]
        class_probability = model.predict_proba([landmarks])[0]
        current_class = pose_classes[predicted_class]
        
        # Render landmarks on the frame
        mp_drawing.draw_landmarks(frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
        if(class_probability[0]<class_probability[1]<.7)|(class_probability[1]<class_probability[0]<.5):
            current_class='Half'

        # Display the predicted class and probability on the frame
        label = current_class
        prob=class_probability
        cv2.putText(frame, label, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        cv2.putText(frame, str(prob), (190, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
    # Display the frame
    cv2.imshow('Pose Classification', frame)
    
    # Quit the program when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close the windows
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...

# %%
import cv2
import mediapipe as mp
import pickle
import numpy as np

# Load the trained pickle model
with open(r"G:\Project\Self video Samples\Bicep curl\/Bcurl_cvs.pkl", 'rb') as f:
    model = pickle.load(f)

# Define the classes for pose classification
pose_classes = {1: 'Down', 2: 'UP',}

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5, min_tracking_confidence=0.5)

# OpenCV setup for video capture
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise Exception("Failed to open the camera.")

# Rep meter configuration
meter_width = 400
meter_height = 20
meter_x = int((cap.get(cv2.CAP_PROP_FRAME_WIDTH) - meter_width) / 2)
meter_y = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT) - meter_height - 20)
meter_fill_color = (0, 255, 0)  # Green color for the filled part
meter_empty_color = (0, 0, 255)  # Red color for the empty part
current_angle = 30  # Initial angle value
angle_range = (30, 160)  # Angle range for interpolation
meter_fill = int((current_angle - angle_range[0]) / (angle_range[1] - angle_range[0]) * meter_width)

while True:
    # Read frame from camera
    ret, frame = cap.read()
    if not ret:
        break

    # Convert BGR image to RGB
    image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame with MediaPipe Pose
    results = pose.process(image_rgb)

    # Check if landmarks are detected
    if results.pose_landmarks:
        # Extract landmarks
        landmarks = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()

        # Perform pose classification using the pickle model
        predicted_class = model.predict([landmarks])[0]
        class_probability = model.predict_proba([landmarks])[0]
        current_class = pose_classes[predicted_class]

        # Render landmarks on the frame
        mp_drawing.draw_landmarks(frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
        if (class_probability[0] < class_probability[1] < .7) or (class_probability[1] < class_probability[0] < .4):
            current_class = 'Half'

        # Display the predicted class and probability on the frame
        label = current_class
        prob = class_probability
        cv2.putText(frame, label, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        cv2.putText(frame, str(prob), (190, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

        # Update rep meter based on elbow angle
        if results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].visibility > 0.5:
            left_elbow_coords = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].x, results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].y
            right_elbow_coords = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW].x, results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW].y
            elbow_angle = np.degrees(np.arctan2(right_elbow_coords[1] - left_elbow_coords[1],
                                                 right_elbow_coords[0] - left_elbow_coords[0]))
            current_angle = int(np.interp(elbow_angle, angle_range, (0, 100)))
            meter_fill = int((current_angle / 100) * meter_width)

    # Draw rep meter on the frame
    cv2.rectangle(frame, (meter_x, meter_y), (meter_x + meter_width, meter_y + meter_height), meter_empty_color, -1)
    cv2.rectangle(frame, (meter_x, meter_y), (meter_x + meter_fill, meter_y + meter_height), meter_fill_color, -1)

    # Display the frame
    cv2.imshow('Pose Classification', frame)

    # Quit the program when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close the windows
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import pickle
import numpy as np

# Load the trained pickle model
with open(r"G:\Project\Self video Samples\Bicep curl\/Bcurl_cvs_Logr.pkl", 'rb') as f:
    model = pickle.load(f)

# Define the classes for pose classification
pose_classes = {1: 'Down', 2: 'UP',}

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5, min_tracking_confidence=0.5)

# OpenCV setup for video capture
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise Exception("Failed to open the camera.")

# Rep meter configuration
meter_width = 20
meter_height = 400
meter_x = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH) - meter_width - 20)
meter_y = int((cap.get(cv2.CAP_PROP_FRAME_HEIGHT) - meter_height) / 2)
meter_fill_color = (0, 255, 0)  # Green color for the filled part
meter_empty_color = (0, 0, 255)  # Red color for the empty part
current_angle = 30  # Initial angle value
angle_range = (30, 160)  # Angle range for interpolation
meter_fill = int((current_angle - angle_range[0]) / (angle_range[1] - angle_range[0]) * meter_height)

while True:
    # Read frame from camera
    ret, frame = cap.read()
    if not ret:
        break

    # Convert BGR image to RGB
    image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame with MediaPipe Pose
    results = pose.process(image_rgb)

    # Check if landmarks are detected
    if results.pose_landmarks:
        # Extract landmarks
        landmarks = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()

        # Perform pose classification using the pickle model
        predicted_class = model.predict([landmarks])[0]
        class_probability = model.predict_proba([landmarks])[0]
        current_class = pose_classes[predicted_class]

        # Render landmarks on the frame
        mp_drawing.draw_landmarks(frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
        if (class_probability[0] < class_probability[1] < .78) or (class_probability[1] < class_probability[0] < .4):
            current_class = 'Half'

        # Display the predicted class and probability on the frame
        label = current_class
        prob = class_probability
        cv2.putText(frame, label, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        cv2.putText(frame, str(prob), (190, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

        # Update rep meter based on elbow angle
        if results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].visibility > 0.5:
            left_elbow_coords = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].x, results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].y
            right_elbow_coords = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW].x, results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW].y
            elbow_angle = np.degrees(np.arctan2(right_elbow_coords[1] - left_elbow_coords[1],
                                                 right_elbow_coords[0] - left_elbow_coords[0]))
            current_angle = int(np.interp(elbow_angle, angle_range, (0, 100)))
            meter_fill = int((current_angle / 100) * meter_height)

    # Draw rep meter on the frame
    cv2.rectangle(frame, (meter_x, meter_y + meter_height - meter_fill), (meter_x + meter_width, meter_y + meter_height), meter_fill_color, -1)
    cv2.rectangle(frame, (meter_x, meter_y), (meter_x + meter_width, meter_y + meter_height), meter_empty_color, 2)

    # Display the frame
    cv2.imshow('Pose Classification', frame)

    # Quit the program when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close the windows
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...

# %%
import cv2
import mediapipe as mp
import pickle
import numpy as np

# Load the trained pickle model
with open(r"G:\Project\Self video Samples\Bicep curl\/Bcurl_cvs_Logr.pkl", 'rb') as f:
    model = pickle.load(f)

# Define the classes for pose classification
pose_classes = {1: 'Down', 2: 'UP',}

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5, min_tracking_confidence=0.5)

# OpenCV setup for video capture
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise Exception("Failed to open the camera.")

# Rep meter configuration
meter_width = 20
meter_height = 400
meter_x = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH) - meter_width - 20)
meter_y = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT) - 20)
meter_fill_color = (0, 255, 0)  # Green color for the filled part
meter_empty_color = (0, 0, 255)  # Red color for the empty part
current_angle = 30  # Initial angle value
angle_range = (30, 160)  # Angle range for interpolation

while True:
    # Read frame from camera
    ret, frame = cap.read()
    if not ret:
        break

    # Convert BGR image to RGB
    image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame with MediaPipe Pose
    results = pose.process(image_rgb)

    # Check if landmarks are detected
    if results.pose_landmarks:
        # Extract landmarks
        landmarks = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()

        # Perform pose classification using the pickle model
        predicted_class = model.predict([landmarks])[0]
        class_probability = model.predict_proba([landmarks])[0]
        current_class = pose_classes[predicted_class]

        # Render landmarks on the frame
        mp_drawing.draw_landmarks(frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
        if (class_probability[0] < class_probability[1] < .65) or (class_probability[1] < class_probability[0] < .4):
            current_class = 'Half'

        # Display the predicted class and probability on the frame
        label = current_class
        prob = class_probability
        cv2.putText(frame, label, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        cv2.putText(frame, str(prob), (190, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

        # Update rep meter based on elbow angle
        if results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].visibility > 0.5:
            left_elbow_coords = results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].x, results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].y
            right_elbow_coords = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW].x, results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW].y
            elbow_angle = np.degrees(np.arctan2(right_elbow_coords[1] - left_elbow_coords[1],
                                                 right_elbow_coords[0] - left_elbow_coords[0]))
            current_angle = int(np.interp(elbow_angle, angle_range, (0, 100)))

    # Calculate the meter fill and empty height based on the current angle
    meter_fill_height = int((current_angle / 100) * meter_height)
    meter_empty_height = meter_height - meter_fill_height

    # Draw rep meter on the frame
    cv2.rectangle(frame, (meter_x, meter_y - meter_fill_height), (meter_x + meter_width, meter_y), meter_fill_color, -1)
    cv2.rectangle(frame, (meter_x, meter_y - meter_height), (meter_x + meter_width, meter_y - meter_fill_height), meter_empty_color, -1)

    # Display the frame
    cv2.imshow('Pose Classification', frame)

    # Quit the program when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close the windows
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...

# %%
import cv2
import mediapipe as mp
import pickle
import numpy as np

# Load the trained pickle model
with open(r"G:\Project\Self video Samples\Bicep curl\/Bcurl_cvs.pkl", 'rb') as f:
    model = pickle.load(f)

# Define the classes for pose classification
pose_classes = {1: 'Down', 2: 'UP',}
shoulder1,shoulder2,elbow1,elbow2,hip1,hip2,a1,a2=0,0,0,0,0,0,0,0

def calculate_angle(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Mid
    c = np.array(c) # End
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle >180.0:
        angle = 360-angle
        
    return angle 

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5, min_tracking_confidence=0.5)

# OpenCV setup for video capture
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise Exception("Failed to open the camera.")

# Rep meter configuration
meter_width = 20
meter_height = 400
meter_x = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH) - meter_width - 20)
meter_y = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT) - 20)
meter_fill_color = (0, 255, 0)  # Green color for the filled part
meter_empty_color = (0, 0, 255)  # Red color for the empty part
current_angle = 30  # Initial angle value
angle_range = (30, 160)  # Angle range for interpolation

while True:
    # Read frame from camera
    ret, frame = cap.read()
    if not ret:
        break

    # Convert BGR image to RGB
    image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame with MediaPipe Pose
    results = pose.process(image_rgb)

    # Check if landmarks are detected
    if results.pose_landmarks:
        # Extract landmarks
        landmarks = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()

        # Perform pose classification using the pickle model
        predicted_class = model.predict([landmarks])[0]
        class_probability = model.predict_proba([landmarks])[0]
        current_class = pose_classes[predicted_class]

        # Render landmarks on the frame
        mp_drawing.draw_landmarks(frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
        if (class_probability[0] < class_probability[1] < .78) or (class_probability[1] < class_probability[0] < .4):
            current_class = 'Half'

        # Display the predicted class and probability on the frame
        label = current_class
        prob = class_probability
        cv2.putText(frame, label, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        cv2.putText(frame, str(prob), (190, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

        # Update rep meter based on elbow angle
        if results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].visibility > 0.5:
            
            shoulder1 = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            shoulder2 = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
            elbow1 = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist1 = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            elbow2 = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            wrist2 = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            hip1=[landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
            hip2=[landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
            a1=calculate_angle(shoulder1,elbow1,wrist1)
            a2=calculate_angle(shoulder2,elbow2,wrist2)
            angle1 = calculate_angle(shoulder1, elbow1, wrist1)
            angle2= calculate_angle(shoulder2, elbow2, wrist2)
            angle3 = calculate_angle( elbow1,shoulder1, hip1)
            angle4 = calculate_angle( elbow2,shoulder2, hip2)

    per_val1 = int(np.interp (a1, (75,175), (100,0)))
    per_val2 = int(np.interp(a2, (75,175), (100,0)))
    bar_val1 = int(np.interp(per_val1, (0,100), (40+350,40)))
# print(per_val1)
    cv2.rectangle(img, (570,bar_val1), (570+35,40+350), (0,0,255),cv2.FILLED)
    cv2.rectangle(img, (570, 40), (570+35, 40+350), (),3)

    # Display the frame
    cv2.imshow('Pose Classification', frame)

    # Quit the program when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close the windows
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 84
#      81 # Update rep meter based on elbow angle
#      82 if results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW].visibility > 0.5:
# ---> 84     shoulder1 = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
# ...
